# %% [markdown]
# # Importing Library

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Importing color images and display results using function from cv2

# %%
fp = r"C:\Users\Thichanon\Desktop\University\COS3401\week2\images\lena_color_256.tif"
img = cv2.imread(fp)

# %%
print(type(img))
print(img.shape)
# Out:
# <class 'numpy.ndarray'>
# (256, 256, 3)

# %%
cv2.imshow("image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 2. Importing color images and display results using functions from matplotlib.pyplot

# %%
plt.axis("off")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.savefig('lenaSAVEFIG.png', bbox_inches='tight', pad_inches=0)

# %% [markdown]
# ## 3. Saving image files

# %%
cv2.imwrite(r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\lena_color_256.tif', img.astype(np.uint8))
# Out:
# True

# %%
del(img)
del(fp)

# %% [markdown]
# ## 4. Converting Color to Grayscale Image

# %% [markdown]
# ### <span style='color:yellow;'>Method I</span>

# %%
fp = r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\test_color.png'
img = cv2.imread(fp)
print(type(img))
print(img.shape)
plt.axis('off')
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (139, 162, 3)

# %%
del(img)
del(fp)

# %% [markdown]
# ### <span style='color: yellow;'>Method II</span>

# %%
fp = r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\test_color.png'
img = cv2.imread(fp)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.axis('off')
plt.imshow(gray, cmap='gray')
plt.show()

# %%
del(img)
del(fp)

# %% [markdown]
# ### <span style='color:yellow;'>Method III : Linear Equation</span>

# %%
fp = r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\mandril_color.tif'
img = cv2.imread(fp)

# %%
r = img[:,:,2].astype(np.float32)
g = img[:,:,1].astype(np.float32)
b = img[:,:,0].astype(np.float32)
#b,g,r = cv2.splite(img)
m,n = r.shape

# %%
gray = np.zeros_like(r, dtype='float')

for i in range(m):
    for j in range(n):
        gray[i, j] = 0.2989*r[i, j] + 0.5870*g[i, j]+ 0.1140*b[i, j]

# %%
plt.axis('off')
plt.imshow(gray, cmap='gray')
plt.show()
cv2.imwrite(r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\output.png', gray.astype(np.uint8))
# Out:
# True
