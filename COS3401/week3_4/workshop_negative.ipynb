# %% [markdown]
# ## <span style='color:lightblue;'>LET'S START</span>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### <span style='color:lightgreen;'>READ GRAY-LEVEL IMAGE</span>

# %%
img = cv2.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\images\cortex.png')

# %%
print(type(255), type(img))
# Out:
# <class 'int'> <class 'numpy.ndarray'>

# %% [markdown]
# ### <span style='color:lightgreen;'>METHOD I OF NEGATIVE TRANSFORM</span>

# %%
neg1 = 255 -img
print(neg1.shape, img.shape)
# Out:
# (443, 443, 3) (443, 443, 3)

# %%
cv2.imshow('test', neg1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(neg1, cmap='gray')
plt.axis('off')
plt.show()

# %%
fig = plt.figure()
fig.add_subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.axis('off')

fig.add_subplot(1,2,2)
plt.imshow(neg1, cmap='gray')
plt.axis('off')

plt.show()

# %%
print(img.shape)
# Out:
# (443, 443, 3)

# %% [markdown]
# ### <span style='color:lightgreen;'>METHOD II OF NEGATIVE TRANSFORM</span>

# %%
neg2 = np.zeros_like(img, dtype='uint8')
row, col = img.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 neg2 = np.zeros_like(img, dtype='uint8')
# ----> 2 row, col = img.shape
#
# ValueError: too many values to unpack (expected 2)

# %%
for i in range(row):
    for j in range(col):
        neg2[i, j] = 255 - img[i,j]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 for i in range(row):
#       2     for j in range(col):
#       3         neg2[i, j] = 255 - img[i,j]
#
# NameError: name 'row' is not defined

# %%
print(img.shape)
# Out:
# (443, 443, 3)

# %%
img = cv2.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\images\lena.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 img = cv2.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\images\lena.png')
#
# NameError: name 'cv2' is not defined

# %%
b_neg =255 -b
g_neg = 255 -g
r_neg = 255-r
neg = cv2.merge((b_neg, g_neg, r_neg))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 b_neg =255 -b
#       2 g_neg = 255 -g
#       3 r_neg = 255-r
#
# NameError: name 'b' is not defined

# %%
fig = plt.figure()
fig.add_subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')

fig.add_subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(neg, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       4 plt.axis('off')
#       6 fig.add_subplot(1, 2, 2)
# ----> 7 plt.imshow(cv2.cvtColor(neg, cv2.COLOR_BGR2RGB))
#       8 plt.axis('off')
#      10 plt.show()
#
# NameError: name 'neg' is not defined
