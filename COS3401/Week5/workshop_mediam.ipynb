# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def plt_show(img):
    plt.axis('off')
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
def cv_show(img):
    cv2.imshow('Mean Filtered Image', img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %% [markdown]
# #### Method 1 using cv library

# %%
def MedianBlur(img, k):
    return cv2.medianBlur(img, 3)

# %% [markdown]
# ### 1. Read Image

# %%
image = cv2.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\Week5\images\lena_salt_512.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print(type(gray), gray.shape)
# Out:
# <class 'numpy.ndarray'> (512, 512)

# %%
blur_img = cv2.medianBlur(gray, 3)
imgs = cv2.hconcat([gray, blur_img])
plt_show(imgs)

# %%
def MedianCustom(img, sz):
    bd = int(sz / 2)
    inx = int(float(sz*sz) / 2.0)
    (m, n) = img.shpae
    out = np.zeros((m,n), dtype = 'float16')
    for i in range(bd, m-bd):
        for j in range(bd, n-bd):
            sub_img = img[i-bd:i+bd+1, j-bd:j+bd+1]
            asort = np.sort(np.ravel(sub_img))
            out[i, j] = asort[inx]
        return out.astype(np.unit8)

# %%
blur_img = MedianCustom(gray, 3)
imgs = cv2.hconcat([gray, blur_img])
plt_show(imgs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 blur_img = MedianCustom(gray, 3)
#       2 imgs = cv2.hconcat([gray, blur_img])
#       3 plt_show(imgs)
#
# Cell In[21], line 4, in MedianCustom(img, sz)
#       2 bd = int(sz / 2)
#       3 inx = int(float(sz*sz) / 2.0)
# ----> 4 (m, n) = img.shpae
#       5 out = np.zeros((m,n), dtype = 'float16')
#       6 for i in range(bd, m-bd):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'shpae'
