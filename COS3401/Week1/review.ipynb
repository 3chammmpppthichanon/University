# %% [markdown]
# # Import skimage

# %%
from skimage import data
rocket_image = data.rocket()
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import neccessary libry for visualizing image

# %%
import numpy as np
import matplotlib.pyplot as plt

def show_image(image, title='Image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')

# %%
from skimage import data
coffee_image = data.coffee()
coins_image = data.coins()

# %%
coffee_image.shape
#Output Height weight and channels
# Out:
# (400, 600, 3)

# %%
coins_image.shape
#Output Rows and Columns
# Out:
# (303, 384)

# %% [markdown]
# # RGB to grayscale

# %%
from skimage import color

rocket = data.rocket()

gray_scaled_rocket = color.rgb2gray(rocket)

show_image(rocket, 'Original RGB image')

# %%
show_image(gray_scaled_rocket, 'Grayscale image')

# %% [markdown]
# # Images as NdArrays

# %%
madrid_image = plt.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\lena_color_256.tif')
type(madrid_image)
# Out:
# numpy.ndarray

# %%
madrid_image.size
# Out:
# 196608

# %% [markdown]
# # Fliping Image: Vertically

# %%
madrid_image = plt.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\lena_color_256.tif')

vertically_flipped = np.flipud(madrid_image)
show_image(vertically_flipped, 'Vertically flipped image')

# %%
horizontally_flipped = np.fliplr(madrid_image)
show_image(horizontally_flipped, 'Horizontally flipped image')

# %%
flipped_seville = plt.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\week2\images\cortex.png')

seville_vertical_flip = np.flipud(flipped_seville)

seville_horizontal_flip = np.fliplr(flipped_seville)

show_image(seville_vertical_flip, 'Vertically flipped image')

# %%
image = plt.imread(r'C:\Users\Thichanon\Desktop\University\COS3401\Week1\lena.png')

red_channel = image[:, :, 0]

plt.hist(red_channel.ravel(), bins=256, color='red')

plt.title('Red Histogram')
# Out:
# Text(0.5, 1.0, 'Red Histogram')
